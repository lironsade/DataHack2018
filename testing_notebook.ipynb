# %%
import pandas as pd
import test

# %%
df = pd.read_json("data/number_word_std.dev.json")

# %%
tags = ['id', 'text', 'equations']

# %%
result = test.check_over_data(df[tags])

# %%
print("succsses rate: {}".format(result[0]))
# Out:
# succsses rate: 0.025925925925925925

# %%
result[1].loc[result[2]]
# Out:
#                      id                                               text  \
# 0    algebra.com.117395  one number is 11 more than another number. Fin...
# 7      algebra.com.3133  The sum of 2 integers is 36. The difference of...
# 9    algebra.com.437200  One number is seven less than another number. ...
# 13   algebra.com.158269  If the first and third of three consecutive ev...
# 14    algebra.com.15515  The sum of three consecutive odd integers is -...
# 15   algebra.com.228612  the sum of three consecutive odd integers is -...
# 16   algebra.com.606748  what three consecutive odd integers have a sum...
# 18   algebra.com.142635  The sum of two numbers is 64. If twice the sma...
# 21   algebra.com.289589  One positive integer is 3 less than a second p...
# 22   algebra.com.367532  Three times the sum of three consecutive integ...
# 23   algebra.com.157265  2 more than 6 times a number is 20 more than 3...
# ...
